# %%
import csv

years = []
decisionDirections = []
decisionsPerYear = {}

with open('case_data.csv', 'rb') as csvrfile:
    csvreader = csv.reader(csvrfile, delimiter=',', quotechar='"')
    next(csvreader, None)  # skip the headers
    for row in csvreader:
        decisionDates = row[4]
        years.append(decisionDates.split('/')[2])
        decisionDirections.append(row[41])
        
for index, value in enumerate(years):
    if value not in decisionsPerYear:
        decisionsPerYear[value] = {
            "liberal": 0,
            "conservative": 0,
            "unspecified": 0
        }
    
    if decisionDirections[index] == "1":
        decisionsPerYear[value]["conservative"] += 1
    if decisionDirections[index] == "2":
        decisionsPerYear[value]["liberal"] += 1
    if decisionDirections[index] == "3":
        decisionsPerYear[value]["unspecified"] += 1
    
with open('ideology_data.csv', 'w') as csvwfile:
    csvwriter = csv.writer(csvwfile)
    csvwriter.writerow(['Year', 'Conservative', 'Liberal', 'Unspecified'])
    for key in sorted(decisionsPerYear.iterkeys()):
        row = [key]
        row.append(decisionsPerYear[key]["conservative"])
        row.append(decisionsPerYear[key]["liberal"])
        row.append(decisionsPerYear[key]["unspecified"])
        csvwriter.writerow(row)
# Out:
#  1946: {'liberal': 15, 'unspecified': 0, 'conservative': 10}
# 1947: {'liberal': 71, 'unspecified': 4, 'conservative': 59}
# 1948: {'liberal': 69, 'unspecified': 2, 'conservative': 44}
# 1949: {'liberal': 72, 'unspecified': 2, 'conservative': 57}
# 1950: {'liberal': 40, 'unspecified': 0, 'conservative': 53}
# 1951: {'liberal': 41, 'unspecified': 3, 'conservative': 54}
# 1952: {'liberal': 44, 'unspecified': 2, 'conservative': 61}
# 1953: {'liberal': 51, 'unspecified': 0, 'conservative': 56}
# 1954: {'liberal': 44, 'unspecified': 0, 'conservative': 43}
# 1955: {'liberal': 62, 'unspecified': 4, 'conservative': 29}
# 1956: {'liberal': 69, 'unspecified': 2, 'conservative': 32}
# 1957: {'liberal': 93, 'unspecified': 0, 'conservative': 44}
# 1958: {'liberal': 91, 'unspecified': 3, 'conservative': 56}
# 1959: {'liberal': 75, 'unspecified': 2, 'conservative': 53}
# 1960: {'liberal': 90, 'unspecified': 1, 'conservative': 52}
# 1961: {'liberal': 77, 'unspecified': 0, 'conservative': 60}
# 1962: {'liberal': 83, 'unspecified': 0, 'conservative': 36}
# 1963: {'liberal': 134, 'unspecified': 3, 'conservative': 33}
# 1964: {'liberal': 132, 'unspecified': 2, 'conservative': 37}
# 1965: {'liberal': 89, 'unspecified': 4, 'conservative': 52}
# 1966: {'liberal': 82, 'unspecified': 2, 'conservative': 53}
# 1967: {'liberal': 124, 'unspecified': 0, 'conservative': 42}
# 1968: {'liberal': 123, 'unspecified': 1, 'conservative': 47}
# 1969: {'liberal': 90, 'unspecified': 1, 'conservative': 46}
# 1970: {'liberal': 69, 'unspecified': 4, 'conservative': 61}
# 1971: {'liberal': 80, 'unspecified': 2, 'conservative': 81}
# 1972: {'liberal': 87, 'unspecified': 3, 'conservative': 83}
# 1973: {'liberal': 85, 'unspecified': 6, 'conservative': 96}
# 1974: {'liberal': 71, 'unspecified': 3, 'conservative': 89}
# 1975: {'liberal': 74, 'unspecified': 2, 'conservative': 79}
# 1976: {'liberal': 70, 'unspecified': 3, 'conservative': 116}
# 1977: {'liberal': 72, 'unspecified': 3, 'conservative': 96}
# 1978: {'liberal': 72, 'unspecified': 0, 'conservative': 85}
# 1979: {'liberal': 67, 'unspecified': 1, 'conservative': 85}
# 1980: {'liberal': 74, 'unspecified': 6, 'conservative': 81}
# 1981: {'liberal': 59, 'unspecified': 5, 'conservative': 88}
# 1982: {'liberal': 82, 'unspecified': 4, 'conservative': 88}
# 1983: {'liberal': 69, 'unspecified': 3, 'conservative': 90}
# 1984: {'liberal': 66, 'unspecified': 3, 'conservative': 102}
# 1985: {'liberal': 73, 'unspecified': 5, 'conservative': 97}
# 1986: {'liberal': 67, 'unspecified': 1, 'conservative': 92}
# 1987: {'liberal': 70, 'unspecified': 3, 'conservative': 87}
# 1988: {'liberal': 77, 'unspecified': 3, 'conservative': 75}
# 1989: {'liberal': 61, 'unspecified': 4, 'conservative': 85}
# 1990: {'liberal': 67, 'unspecified': 2, 'conservative': 74}
# 1991: {'liberal': 60, 'unspecified': 4, 'conservative': 67}
# 1992: {'liberal': 56, 'unspecified': 0, 'conservative': 57}
# 1993: {'liberal': 52, 'unspecified': 4, 'conservative': 62}
# 1994: {'liberal': 40, 'unspecified': 1, 'conservative': 55}
# 1995: {'liberal': 37, 'unspecified': 5, 'conservative': 51}
# 1996: {'liberal': 42, 'unspecified': 0, 'conservative': 49}
# 1997: {'liberal': 37, 'unspecified': 0, 'conservative': 61}
# 1998: {'liberal': 37, 'unspecified': 3, 'conservative': 56}
# 1999: {'liberal': 30, 'unspecified': 2, 'conservative': 61}
# 2000: {'liberal': 44, 'unspecified': 0, 'conservative': 40}
# 2001: {'liberal': 38, 'unspecified': 3, 'conservative': 46}
# 2002: {'liberal': 34, 'unspecified': 0, 'conservative': 52}
# 2003: {'liberal': 35, 'unspecified': 2, 'conservative': 44}
# 2004: {'liberal': 35, 'unspecified': 2, 'conservative': 46}
# 2005: {'liberal': 44, 'unspecified': 0, 'conservative': 37}
# 2006: {'liberal': 32, 'unspecified': 1, 'conservative': 47}
# 2007: {'liberal': 33, 'unspecified': 0, 'conservative': 43}
# 2008: {'liberal': 36, 'unspecified': 1, 'conservative': 35}
# 2009: {'liberal': 32, 'unspecified': 2, 'conservative': 52}
# 2010: {'liberal': 44, 'unspecified': 1, 'conservative': 42}
# 2011: {'liberal': 36, 'unspecified': 2, 'conservative': 49}
# 2012: {'liberal': 34, 'unspecified': 1, 'conservative': 41}
# 2013: {'liberal': 41, 'unspecified': 0, 'conservative': 43}
# 2014: {'liberal': 38, 'unspecified': 1, 'conservative': 30}
# 2015: {'liberal': 40, 'unspecified': 1, 'conservative': 31}
# 2016: {'liberal': 41, 'unspecified': 1, 'conservative': 38}
# 2017: {'liberal': 34, 'unspecified': 1, 'conservative': 32}
# 2018: {'liberal': 32, 'unspecified': 6, 'conservative': 33}
